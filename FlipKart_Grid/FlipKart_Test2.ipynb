# %%
# !git clone https://github.com/dragonslayer01/ssd.pytorch
# Out:
# Cloning into 'ssd.pytorch'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 1435 (delta 0), reused 0 (delta 0), pack-reused 1434
# Receiving objects: 100% (1435/1435), 106.31 MiB | 32.92 MiB/s, done.
# Resolving deltas: 100% (867/867), done.

# %%
# !ls ssd.pytorch
# Out:
# data  doc      layers	README.md  test.py   utils
# demo  eval.py  LICENSE	ssd.py	   train.py

# %%
# !python ssd.pytorch/eval.py
# Out:
# Traceback (most recent call last):
#   File "ssd.pytorch/eval.py", line 12, in <module>
#     from data import VOC_ROOT, VOCAnnotationTransform, VOCDetection, BaseTransform
#   File "/content/ssd.pytorch/data/__init__.py", line 3, in <module>
#     from .coco import COCODetection, COCOAnnotationTransform, COCO_CLASSES, COCO_ROOT, get_label_map
#   File "/content/ssd.pytorch/data/coco.py", line 75, in <module>
#     class COCODetection(data.Dataset):
#   File "/content/ssd.pytorch/data/coco.py", line 87, in COCODetection
#     target_transform=COCOAnnotationTransform(), dataset_name='MS COCO'):
#   File "/content/ssd.pytorch/data/coco.py", line 47, in __init__
#     self.label_map = get_label_map(osp.join(COCO_ROOT, 'coco_labels.txt'))
#   File "/content/ssd.pytorch/data/coco.py", line 35, in get_label_map
#     labels = open(label_file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: '/root/data/coco/coco_labels.txt'

# %%
# !mkdir weights

# %%
# !cd weights

# %%
# !ls weights

# %%
# !cd ..

# %%
# !ls
# Out:
# sample_data  ssd.pytorch  weights

# %%
# !cd ssd.pytorch

# %%
# !ls
# Out:
# sample_data  ssd.pytorch  weights

# %%
# !mkdir ssd.pytorch/weights

# %%
# !ls ssd.pytorch
# Out:
# data  doc      layers	README.md  test.py   utils
# demo  eval.py  LICENSE	ssd.py	   train.py  weights

# %%
# !cd ssd.pytorch/weights

# %%
# !wget https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Out:
# --2019-02-06 04:23:33--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.64.51
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.64.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘vgg16_reducedfc.pth.2’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  34.2MB/s    in 2.3s
#
# 2019-02-06 04:23:36 (34.2 MB/s) - ‘vgg16_reducedfc.pth.2’ saved [81938914/81938914]

# %%
# !ls ssd.pytorch/weights

# %%
# !mv vgg16_reducedfc.pth ssd.pytorch/weights

# %%
# !ls ssd.pytorch/weights
# Out:
# vgg16_reducedfc.pth

# %%
# !python ssd.pytorch/eval.py
# Out:
# Traceback (most recent call last):
#   File "ssd.pytorch/eval.py", line 12, in <module>
#     from data import VOC_ROOT, VOCAnnotationTransform, VOCDetection, BaseTransform
#   File "/content/ssd.pytorch/data/__init__.py", line 3, in <module>
#     from .coco import COCODetection, COCOAnnotationTransform, COCO_CLASSES, COCO_ROOT, get_label_map
#   File "/content/ssd.pytorch/data/coco.py", line 75, in <module>
#     class COCODetection(data.Dataset):
#   File "/content/ssd.pytorch/data/coco.py", line 87, in COCODetection
#     target_transform=COCOAnnotationTransform(), dataset_name='MS COCO'):
#   File "/content/ssd.pytorch/data/coco.py", line 47, in __init__
#     self.label_map = get_label_map(osp.join(COCO_ROOT, 'coco_labels.txt'))
#   File "/content/ssd.pytorch/data/coco.py", line 35, in get_label_map
#     labels = open(label_file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: '/root/data/coco/coco_labels.txt'

# %%
# !sh ssd.pytorch/data/scripts/COCO2014.sh
